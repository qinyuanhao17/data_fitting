# %%
import numpy as np
from lmfit import *
import openpyxl as xl
import matplotlib.pyplot as plt

# %%
wb = xl.load_workbook(r'D:\confocal_pl_locating\wxd_20221216_50s\upper_point_vertical.xlsx')
sheet = wb['upper_point_vertical']
pix = []
for col in range(3, sheet.max_column+1):
    cell = sheet.cell(1,col)
    pix.append(cell.value)
intensity = []
for col in range(3, sheet.max_column+1):
    cell = sheet.cell(3,col)
    intensity.append(cell.value)

plt.plot(pix, intensity)
plt.show()

# %%
x_data = pix[100:250]
y_data = intensity[100:250]

plt.scatter(x_data,y_data)
plt.show()

# %%
def gaussian(x,a):
    g = a[0]/(a[1]*np.sqrt(np.pi/(4*np.log(2))))*np.exp(-4*np.log(2)*(x-a[2])**2/a[1]**2)+a[3]
    return g
params = Parameters()
params.add('a1', value = 800000)
params.add('a2', value = 20)
params.add('a3', value = 175)
params.add('a4', value = 10000)

def get_residual(params, x, data):
    a1 = params['a1'].value
    a2 = params['a2'].value
    a3 = params['a3'].value
    a4 = params['a4'].value

    model = a1/(a2*np.sqrt(np.pi/(4*np.log(2))))*np.exp(-4*np.log(2)*(x-a3)**2/a2**2)+a4
    return model - data

out = minimize(get_residual, params, args = (x_data, y_data))
a = [0,0,0,0]
a[0] = out.params['a1'].value
a[1] = out.params['a2'].value
a[2] = out.params['a3'].value
a[3] = out.params['a4'].value

x = np.linspace(100,250,1000)
y = gaussian(x,a)
plt.scatter(x_data,y_data)
plt.plot(x,y,'r')
plt.show()

# %%
out
# Out:
# <h2>Fit Statistics</h2><table><tr><td>fitting method</td><td>leastsq</td><td></td></tr><tr><td># function evals</td><td>36</td><td></td></tr><tr><td># data points</td><td>150</td><td></td></tr><tr><td># variables</td><td>4</td><td></td></tr><tr><td>chi-square</td><td> 1.3524e+08</td><td></td></tr><tr><td>reduced chi-square</td><td> 926300.741</td><td></td></tr><tr><td>Akaike info crit.</td><td> 2064.78883</td><td></td></tr><tr><td>Bayesian info crit.</td><td> 2076.83138</td><td></td></tr></table><h2>Variables</h2><table><tr><th> name </th><th> value </th><th> standard error </th><th> relative error </th><th> initial value </th><th> min </th><th> max </th><th> vary </th></tr><tr><td> a1 </td><td>  1024825.64 </td><td>  8474.80916 </td><td> (0.83%) </td><td> 800000 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a2 </td><td>  22.6363302 </td><td>  0.19001869 </td><td> (0.84%) </td><td> 20 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a3 </td><td>  165.901505 </td><td>  0.07452783 </td><td> (0.04%) </td><td> 175 </td><td>        -inf </td><td>         inf </td><td> True </td></tr><tr><td> a4 </td><td>  8543.34240 </td><td>  96.7855595 </td><td> (1.13%) </td><td> 10000 </td><td>        -inf </td><td>         inf </td><td> True </td></tr></table><h2>Correlations (unreported correlations are < 0.100)</h2><table><tr><td>a1</td><td>a2</td><td>0.6567</td></tr><tr><td>a1</td><td>a4</td><td>-0.5838</td></tr><tr><td>a2</td><td>a4</td><td>-0.3834</td></tr></table>

# %%
error_px = out.params['a3'].stderr
print(error_px)
error_nm = 4.6*error_px
error_nm
# Out:
# 0.07452782819706709
# 0.34282800970650856
