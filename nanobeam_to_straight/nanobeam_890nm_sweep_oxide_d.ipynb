# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# from lmfit import minimize, Parameters, report_fit

# %%
k = np.array(range(1,9))*100
q = [608.05,
1735.4,
10431,
70855,
4.24E+05,
1.43E+06,
1.81E+06,
2.06E+06
]

fig, ax = plt.subplots()
ax.plot(k,q)
ax.set_xlabel('d(nm)')
ax.set_ylabel('Qfactor')
ax.set_yscale('log')

# %%
k = np.array(range(1,15))*100
q = np.array([1.14E+05,
1.01E+05,
17843,
24788,
33080,
19329,
8460.5,
4852,
6028.3,
8983.3,
11683,
14785,
17114,
17681,
])
fig, ax = plt.subplots()
ax.plot(k,q)
ax.set_xlabel('d(nm)')
ax.set_ylabel('Qfactor')
ax.set_yscale('log')
